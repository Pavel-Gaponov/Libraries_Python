# %%
import numpy as np
import pandas as pd

sales = pd.read_csv('Sales.csv')

# %%
sales.head(5)
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
sales.shape
# Out:
# (1000, 14)

# %%
sales_Chad = sales[sales.Country == 'Chad']
sales_Chad
# Out:
#                  Region Country        Item Type Sales Channel Order Priority  \
# 4    Sub-Saharan Africa    Chad           Fruits       Offline              H
# 28   Sub-Saharan Africa    Chad             Meat       Offline              H
# 175  Sub-Saharan Africa    Chad  Office Supplies       Offline              C
# 394  Sub-Saharan Africa    Chad           Fruits       Offline              C
# 401  Sub-Saharan Africa    Chad             Meat       Offline              M
# 811  Sub-Saharan Africa    Chad        Baby Food       Offline              H
# 853  Sub-Saharan Africa    Chad  Office Supplies        Online              H
#
#     Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 4    8/16/2011  645713555   8/31/2011        9845        9.33       6.92
# 28   1/20/2016  357222878    3/9/2016        9043      421.89     364.69
# 175  9/17/2011  364818465  10/16/2011        6746      651.21     524.96
# ...

# %%
sales_Chad.shape
# Out:
# (7, 14)

# %%
sales_Chad.Region[4]
# Out:
# 'Sub-Saharan Africa'

# %%
sales_Chad = sales_Chad.drop(columns=['Sales Channel'])
sales_Chad
# Out:
#                  Region Country        Item Type Order Date   Order ID  \
# 4    Sub-Saharan Africa    Chad           Fruits  8/16/2011  645713555
# 28   Sub-Saharan Africa    Chad             Meat  1/20/2016  357222878
# 175  Sub-Saharan Africa    Chad  Office Supplies  9/17/2011  364818465
# 394  Sub-Saharan Africa    Chad           Fruits  11/5/2010  430081975
# 401  Sub-Saharan Africa    Chad             Meat  3/25/2012  479447925
# 811  Sub-Saharan Africa    Chad        Baby Food   8/9/2016  579379737
# 853  Sub-Saharan Africa    Chad  Office Supplies  6/25/2014  444540584
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 4     8/31/2011        9845        9.33       6.92       91853.85    68127.40
# 28     3/9/2016        9043      421.89     364.69     3815151.27  3297891.67
# 175  10/16/2011        6746      651.21     524.96     4393062.66  3541380.16
# 394   12/9/2010        9669        9.33       6.92       90211.77    66909.48
# ...

# %%
sales_Chad_Meat = sales_Chad[sales_Chad['Item Type'] == 'Meat']

# %%
sales_Chad_Meat['Units Sold'].sum()
# Out:
# 17193

# %%
DICT = {'Model' : ['Logistic Regression', 'SVM', 'KNN', 'Decision'], 'Accuracy' : [0.96, None, None, 0.67]}
df = pd.DataFrame(DICT)
df
# Out:
#                  Model  Accuracy
# 0  Logistic Regression      0.96
# 1                  SVM       NaN
# 2                  KNN       NaN
# 3             Decision      0.67

# %%
df1 = df.fillna(0)
df1
# Out:
#                  Model  Accuracy
# 0  Logistic Regression      0.96
# 1                  SVM      0.00
# 2                  KNN      0.00
# 3             Decision      0.67

# %%
df3 = df.fillna(df['Accuracy'].min())
df3
# Out:
#                  Model  Accuracy
# 0  Logistic Regression      0.96
# 1                  SVM      0.67
# 2                  KNN      0.67
# 3             Decision      0.67

# %%
df4 = df.dropna()
df4
# Out:
#                  Model  Accuracy
# 0  Logistic Regression      0.96
# 3             Decision      0.67

# %%
df.fillna(method='bfill')
# Out:
#                  Model  Accuracy
# 0  Logistic Regression      0.96
# 1                  SVM      0.67
# 2                  KNN      0.67
# 3             Decision      0.67

# %%
df.fillna(method='ffill')
# Out:
#                  Model  Accuracy
# 0  Logistic Regression      0.96
# 1                  SVM      0.96
# 2                  KNN      0.96
# 3             Decision      0.67

# %%
DICT = {'Организация' : ['Яндекс', 'Сбербанк', 'Мираторг', 'Яндекс', 'Mail.ru Group', 'Сбербанк', 'Яндекс'],
       'Форма организации' : ['ООО', 'ОАО', 'ООО', 'ООО', 'ООО', 'ПАО', 'ООО']}
df = pd.DataFrame(DICT)
df
# Out:
#      Организация Форма организации
# 0         Яндекс               ООО
# 1       Сбербанк               ОАО
# 2       Мираторг               ООО
# 3         Яндекс               ООО
# 4  Mail.ru Group               ООО
# 5       Сбербанк               ПАО
# 6         Яндекс               ООО

# %%
df.drop_duplicates()
# Out:
#      Организация Форма организации
# 0         Яндекс               ООО
# 1       Сбербанк               ОАО
# 2       Мираторг               ООО
# 4  Mail.ru Group               ООО
# 5       Сбербанк               ПАО

# %%
df.drop_duplicates(subset='Организация')
# Out:
#      Организация Форма организации
# 0         Яндекс               ООО
# 1       Сбербанк               ОАО
# 2       Мираторг               ООО
# 4  Mail.ru Group               ООО

# %%
df.drop_duplicates(subset='Организация', keep='last')
# Out:
#      Организация Форма организации
# 2       Мираторг               ООО
# 4  Mail.ru Group               ООО
# 5       Сбербанк               ПАО
# 6         Яндекс               ООО
